# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
243628 - 176117
# Out:
# 67511

# %%
176117 - 127914
# Out:
# 48203

# %%
127914 - 90343
# Out:
# 37571

# %%
90343 - 78331
# Out:
# 12012

# %%
78331 - 70092
# Out:
# 8239

# %%
70092 - 61560
# Out:
# 8532

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_250_shuffle.csv", header=None))
# Out:
# 61560

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_200_shuffle.csv", header=None))
# Out:
# 70092

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_150_shuffle.csv", header=None))
# Out:
# 78331

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_100_shuffle.csv", header=None))
# Out:
# 90343

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_50_shuffle.csv", header=None))
# Out:
# 127914

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_25_shuffle.csv", header=None))
# Out:
# 176117

# %%
len(pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_0_shuffle.csv", header=None))
# Out:
# 243628

# %%
data = pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren.csv", header=None)

# %%
data.groupby(0).nunique()
# Out:
#                             1
# 0
# Bird                     4742
# Blank                   23956
# Buffalo_African          4826
# Cat_Golden                276
# Chevrotain_Water         3461
# Chimpanzee               4133
# Civet_African_Palm        716
# Duiker_Blue             23997
# Duiker_Red              23945
# Duiker_Yellow_Backed    11537
# Elephant_African        24054
# Genet                    2353
# Gorilla                   461
# Guineafowl_Black         9403
# Guineafowl_Crested       1159
# Hog_Red_River           18020
# Human                   24104
# Leopard_African          1216
# Mandrillus               5306
# Mongoose                 4165
# Mongoose_Black_Footed    1052
# Monkey                   3025
# Pangolin                  586
# Porcupine_Brush_Tailed  10214
# Rail_Nkulengu            2562
# Rat_Giant               25013
# Rodent                    815
# Squirrel                 8531

# %%
data25 = pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/train_data_siebren_series_25.csv", header=None)

# %%
new = data.loc[~((data[1].isin(data25[1]))),:]

# %%
new.groupby(0).nunique()
# Out:
#                             1
# 0
# Bird                     1786
# Blank                     491
# Buffalo_African            71
# Cat_Golden                 74
# Chevrotain_Water          349
# Chimpanzee                430
# Civet_African_Palm        287
# Duiker_Blue              6713
# Duiker_Red               5058
# Duiker_Yellow_Backed     5033
# Elephant_African          993
# Genet                    1234
# Gorilla                    38
# Guineafowl_Black         3134
# Guineafowl_Crested         73
# Hog_Red_River            4602
# Human                    2227
# Leopard_African           144
# Mandrillus               1691
# Mongoose                 2097
# Mongoose_Black_Footed     422
# Monkey                    964
# Pangolin                  255
# Porcupine_Brush_Tailed   5854
# Rail_Nkulengu            1349
# Rat_Giant               16647
# Rodent                    210
# Squirrel                 5285

# %%
def show_img(filename):
    img = tf.io.read_file(filename=filename)
    # Convert the compressed string to a 3D uint8 tensor.
    img = tf.image.decode_jpeg(img, channels=3)
    # Use `convert_image_dtype` to convert to floats in the [0,1] range.
    img = tf.image.convert_image_dtype(img, tf.float32)
    plt.figure(figsize = (16,16))
    plt.imshow(img)
    return img

# %%
test_data_myan = pd.read_csv("gs://dataset-gabon/train_val_test_csv_Siebren/test_data_myanmar_siebren.csv", header=None)

# %%
# plt.ion()
# for i in range(len(test_data_myan)):
#     if data[0][i] == "Elephant_African":      
#         show_img(data[1][i])

# %%
img = show_img(data[1][1])
